# %%
import pandas as pd #data frame lib
import matplotlib.pyplot as plt #plotting to visualize correlation
import scipy.stats as stats #library has multiple analysis methods
df = pd.read_csv('gss2020_small_new.csv')

# %%
#This will permanantly drop col named AGEGR10
df = df.drop( columns=['AGEGR10'], axis = 1)
#This will remove all rows that have missing data
df.dropna()
# Out:
#       PUMFID   WGHT_PER  MARSTAT  PHSDFLG  HSDSIZ_C  GENDER2P  GENPR2P  \
# 0       1000  4056.4189        5        2         3         2        9
# 1       1001    10.0000        6        2         1         1        9
# 2       1002    10.0000        1        1         4         2        1
# 3       1003    10.0000        6        2         1         1        9
# 4       1004   490.8961        1        1         6         2        1
# ...      ...        ...      ...      ...       ...       ...      ...
# 3774    4774  2453.7750        3        2         1         2        9
# 3775    4775    88.0569        5        2         2         2        9
# 3776    4776    10.0000        5        2         3         2        9
# 3777    4777    10.0000        6        2         1         1        9
# 3778    4778  1893.0287        1        1         2         1        2
#
#       CHH001_C  CXRFLAG  LIVARR_C  ...  RELIGFLG  REL_02  REL_03  RIC_01  \
# 0            0        1         3  ...       1.0     5.0     6.0     1.0
# 1            0        2         3  ...       1.0     4.0     5.0     1.0
# 2            2        1         3  ...       1.0     5.0     1.0     1.0
# 3            0        2         3  ...       1.0     5.0     6.0     3.0
# 4            3        1         3  ...       1.0     5.0     4.0     1.0
# ...        ...      ...       ...  ...       ...     ...     ...     ...
# 3774         0        2         3  ...       1.0     1.0     2.0     1.0
# 3775         0        2         3  ...       1.0     5.0     1.0     1.0
# 3776         1        1         3  ...       1.0     1.0     2.0     1.0
# 3777         0        2         3  ...       1.0     4.0     6.0     1.0
# 3778         0        2         3  ...       1.0     5.0     6.0     1.0
#
#       RLR_110  LAN_01  LANHSD_C  LANCH_C  INC_C  FAMINC_C
# 0         3.0     1.0       1.0      1.0    2.0       4.0
# 1         2.0     2.0       3.0      3.0    3.0       3.0
# 2         1.0     3.0       3.0      3.0    1.0       3.0
# 3         1.0     2.0       4.0      3.0    1.0       1.0
# 4         4.0     1.0       1.0      1.0    2.0       5.0
# ...       ...     ...       ...      ...    ...       ...
# 3774      1.0     1.0       3.0      3.0    1.0       1.0
# 3775      1.0     1.0       1.0      1.0    2.0       2.0
# 3776      1.0     1.0       1.0      3.0    3.0       5.0
# 3777      3.0     3.0       3.0      3.0    3.0       3.0
# 3778      2.0     1.0       3.0      3.0    3.0       5.0
#
# [3779 rows x 263 columns]

# %%
# Chekc if AGEGR10 has been removed correctly
'AGEGR10' in df.columns
df.axes # Allows you to see all axes of dataframe
# Out:
# [RangeIndex(start=0, stop=3780, step=1),
#  Index(['PUMFID', 'WGHT_PER', 'MARSTAT', 'PHSDFLG', 'HSDSIZ_C', 'GENDER2P',
#         'GENPR2P', 'CHH001_C', 'CXRFLAG', 'LIVARR_C',
#         ...
#         'RELIGFLG', 'REL_02', 'REL_03', 'RIC_01', 'RLR_110', 'LAN_01',
#         'LANHSD_C', 'LANCH_C', 'INC_C', 'FAMINC_C'],
#        dtype='object', length=263)]

# %%
# Univariate Analysis
df.describe() #gives alot of info on each coloumn including mean and standard deveation as well as min and max
df.mode(axis='rows', numeric_only=True)#df.median(axis='rows', numeric_only=True)
df.median(axis='columns', numeric_only=True)
df.std(axis='columns', numeric_only=True)
df.mean(axis = "rows")
# Out:
# PUMFID      2889.500000
# WGHT_PER     933.012388
# MARSTAT        3.233598
# PHSDFLG        1.467196
# HSDSIZ_C       2.476190
#                ...
# LAN_01         2.189997
# LANHSD_C      10.419688
# LANCH_C       10.822969
# INC_C          2.491135
# FAMINC_C       3.416777
# Length: 263, dtype: float64

# %% [markdown]
# Bivariate

# %%
#T-test, gives result and p-value
groupOne = df["WGHT_PER"]
groupTwo = df["GENPR2P"]
stats.ttest_ind(groupOne, groupTwo)
# Out:
# TtestResult(statistic=37.105054909649674, pvalue=5.263662979952745e-277, df=7558.0)

# %%
#ANOVA, gives result and p-value
#One-way
groupOne = df["WGHT_PER"]
groupTwo = df["GENPR2P"]
stats.f_oneway(groupOne, groupTwo)
# Out:
# F_onewayResult(statistic=1376.7850998481167, pvalue=5.263662979970296e-277)

# %%
#Crosstab
groupOne = df["WGHT_PER"]
groupTwo = df["GENPR2P"]
pd.crosstab(groupOne,groupTwo)  #chi square test with ony catagorical variabels
#pd.crosstab(groupOne,groupTwo, normalize="true")    this will noramlize all values
# Out:
# GENPR2P       1    2    9
# WGHT_PER
# 10.0000     192  362  565
# 10.0171       1    0    1
# 10.0286       0    0    1
# 10.0338       0    0    1
# 10.0592       1    0    0
# ...         ...  ...  ...
# 13997.2938    0    0    1
# 14255.2575    0    0    1
# 14336.0155    0    1    0
# 14441.6578    0    1    0
# 15791.0841    0    0    1
#
# [2525 rows x 3 columns]
